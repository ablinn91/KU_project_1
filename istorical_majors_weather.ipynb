# %%
import os
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import json
from pprint import pprint
from stats import median

csvpath = os.path.join("Data", "city_codes.csv")
csvpath = os.path.join("Data", "majors_dates.csv")
csvpath = os.path.join("Data", "rift_weath_sol_equ.csv")

# %%
city_codes_csv = "Data/city_codes.csv"

# %%
city_codes_df = pd.read_csv(city_codes_csv)

# %%
major_dates_csv = "Data/majors_dates.csv"

# %%
major_dates_df = pd.read_csv(major_dates_csv)

# %%
major_dates_df
# Out:
#       major city_code   13 majors   14 majors   15 majors   16 majors  \
# 0     Tokyo       TYO  2013/02/24  2014/02/23  2015/02/22  2016/02/28
# 1    Boston       BOS  2013/04/15  2014/04/21  2015/04/20  2016/04/18
# 2    London       GBR  2013/04/21  2014/04/13  2015/04/26  2016/04/24
# 3    Berlin       BER  2013/09/29  2014/09/28  2015/09/27  2016/09/25
# 4   Chicago       CHI  2013/10/13  2014/10/12  2015/10/11  2016/10/09
# 5  New York       NYC  2013/11/03  2014/11/02  2015/11/01  2016/11/06
#
#     17 majors   18 majors
# 0  2017/02/28  2018/02/25
# 1  2017/04/17  2018/04/16
# 2  2017/04/23  2018/04/22
# 3  2017/09/24  2018/09/16
# 4  2017/10/08  2018/10/13
# 5  2017/11/05  2018/11/04

# %%
city_13_list = []
feel_13_list = []


url = "https://api.worldweatheronline.com/premium/v1/past-weather.ashx"
params = {
    "key": "bc1fb38cb0ec446b83221156192908",  
    "tp": 24,
    "format": "json",    
}

for index, row in major_dates_df.iterrows():
 
    params['q'] = row['major']
    params['date'] = row['13 majors']
    
    response = requests.get(url, params=params).json()
    
    city_13_list.append(row['major'])
    feel_13_list.append((response['data']['weather'][0]['hourly'][0]['FeelsLikeF']))
    pprint(response)
# Out:
# {'data': {'request': [{'query': 'Tokyo, Japan', 'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '99',
#                                       'moon_phase': 'Full Moon',
#                                       'moonrise': '04:05 PM',
#                                       'moonset': '04:51 AM',
#                                       'sunrise': '06:18 AM',
#                                       'sunset': '05:32 PM'}],
#                        'avgtempC': '3',
#                        'avgtempF': '38',
#                        'date': '2013-02-24',
#                        'hourly': [{'DewPointC': '-6',
#                                    'DewPointF': '22',
#                                    'FeelsLikeC': '0',
#                                    'FeelsLikeF': '33',
#                                    'HeatIndexC': '4',
#                                    'HeatIndexF': '39',
#                                    'WindChillC': '0',
#                                    'WindChillF': '33',
#                                    'WindGustKmph': '26',
#                                    'WindGustMiles': '16',
#                                    'cloudcover': '18',
#                                    'humidity': '50',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.0',
#                                    'pressure': '1017',
#                                    'pressureInches': '31',
#                                    'tempC': '6',
#                                    'tempF': '44',
#                                    'time': '24',
#                                    'uvIndex': '2',
#                                    'visibility': '10',
#                                    'visibilityMiles': '6',
#                                    'weatherCode': '113',
#                                    'weatherDesc': [{'value': 'Sunny'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#                                    'winddir16Point': 'WNW',
#                                    'winddirDegree': '285',
#                                    'windspeedKmph': '20',
#                                    'windspeedMiles': '12'}],
#                        'maxtempC': '6',
#                        'maxtempF': '44',
#                        'mintempC': '0',
#                        'mintempF': '33',
#                        'sunHour': '7.2',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '2'}]}}
# {'data': {'request': [{'query': 'Boston, United States of America',
#                        'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '31',
#                                       'moon_phase': 'Waxing Crescent',
#                                       'moonrise': '09:23 AM',
#                                       'moonset': 'No moonset',
#                                       'sunrise': '06:03 AM',
#                                       'sunset': '07:26 PM'}],
#                        'avgtempC': '7',
#                        'avgtempF': '45',
#                        'date': '2013-04-15',
#                        'hourly': [{'DewPointC': '3',
#                                    'DewPointF': '37',
#                                    'FeelsLikeC': '6',
#                                    'FeelsLikeF': '43',
#                                    'HeatIndexC': '8',
#                                    'HeatIndexF': '46',
#                                    'WindChillC': '6',
#                                    'WindChillF': '43',
#                                    'WindGustKmph': '15',
#                                    'WindGustMiles': '9',
#                                    'cloudcover': '19',
#                                    'humidity': '71',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.0',
#                                    'pressure': '1027',
#                                    'pressureInches': '31',
#                                    'tempC': '11',
#                                    'tempF': '53',
#                                    'time': '24',
#                                    'uvIndex': '3',
#                                    'visibility': '10',
#                                    'visibilityMiles': '6',
#                                    'weatherCode': '113',
#                                    'weatherDesc': [{'value': 'Sunny'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#                                    'winddir16Point': 'SSE',
#                                    'winddirDegree': '168',
#                                    'windspeedKmph': '10',
#                                    'windspeedMiles': '6'}],
#                        'maxtempC': '11',
#                        'maxtempF': '53',
#                        'mintempC': '3',
#                        'mintempF': '37',
#                        'sunHour': '10.4',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '3'}]}}
# {'data': {'request': [{'query': 'London, United Kingdom', 'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '76',
#                                       'moon_phase': 'Waxing Gibbous',
#                                       'moonrise': '03:08 PM',
#                                       'moonset': '03:39 AM',
#                                       'sunrise': '05:52 AM',
#                                       'sunset': '08:07 PM'}],
#                        'avgtempC': '6',
#                        'avgtempF': '43',
#                        'date': '2013-04-21',
#                        'hourly': [{'DewPointC': '4',
#                                    'DewPointF': '39',
#                                    'FeelsLikeC': '8',
#                                    'FeelsLikeF': '47',
#                                    'HeatIndexC': '9',
#                                    'HeatIndexF': '48',
#                                    'WindChillC': '8',
#                                    'WindChillF': '47',
#                                    'WindGustKmph': '12',
#                                    'WindGustMiles': '7',
#                                    'cloudcover': '23',
#                                    'humidity': '74',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.0',
#                                    'pressure': '1022',
#                                    'pressureInches': '31',
#                                    'tempC': '14',
#                                    'tempF': '57',
#                                    'time': '24',
#                                    'uvIndex': '3',
#                                    'visibility': '10',
#                                    'visibilityMiles': '6',
#                                    'weatherCode': '113',
#                                    'weatherDesc': [{'value': 'Sunny'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#                                    'winddir16Point': 'SSW',
#                                    'winddirDegree': '209',
#                                    'windspeedKmph': '7',
#                                    'windspeedMiles': '5'}],
#                        'maxtempC': '14',
#                        'maxtempF': '57',
#                        'mintempC': '-3',
#                        'mintempF': '27',
#                        'sunHour': '13.4',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '3'}]}}
# {'data': {'request': [{'query': 'Berlin, Germany', 'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '23',
#                                       'moon_phase': 'Last Quarter',
#                                       'moonrise': '12:54 AM',
#                                       'moonset': '04:06 PM',
#                                       'sunrise': '07:04 AM',
#                                       'sunset': '06:48 PM'}],
#                        'avgtempC': '9',
#                        'avgtempF': '48',
#                        'date': '2013-09-29',
#                        'hourly': [{'DewPointC': '5',
#                                    'DewPointF': '41',
#                                    'FeelsLikeC': '7',
#                                    'FeelsLikeF': '45',
#                                    'HeatIndexC': '9',
#                                    'HeatIndexF': '49',
#                                    'WindChillC': '7',
#                                    'WindChillF': '45',
#                                    'WindGustKmph': '23',
#                                    'WindGustMiles': '15',
#                                    'cloudcover': '21',
#                                    'humidity': '77',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.0',
#                                    'pressure': '1019',
#                                    'pressureInches': '31',
#                                    'tempC': '14',
#                                    'tempF': '58',
#                                    'time': '24',
#                                    'uvIndex': '3',
#                                    'visibility': '7',
#                                    'visibilityMiles': '4',
#                                    'weatherCode': '113',
#                                    'weatherDesc': [{'value': 'Sunny'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#                                    'winddir16Point': 'E',
#                                    'winddirDegree': '85',
#                                    'windspeedKmph': '15',
#                                    'windspeedMiles': '9'}],
#                        'maxtempC': '14',
#                        'maxtempF': '58',
#                        'mintempC': '5',
#                        'mintempF': '41',
#                        'sunHour': '11.4',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '3'}]}}
# {'data': {'request': [{'query': 'Chicago, United States of America',
#                        'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '58',
#                                       'moon_phase': 'First Quarter',
#                                       'moonrise': '03:07 PM',
#                                       'moonset': '01:05 AM',
#                                       'sunrise': '07:01 AM',
#                                       'sunset': '06:12 PM'}],
#                        'avgtempC': '13',
#                        'avgtempF': '56',
#                        'date': '2013-10-13',
#                        'hourly': [{'DewPointC': '6',
#                                    'DewPointF': '43',
#                                    'FeelsLikeC': '13',
#                                    'FeelsLikeF': '55',
#                                    'HeatIndexC': '14',
#                                    'HeatIndexF': '57',
#                                    'WindChillC': '13',
#                                    'WindChillF': '55',
#                                    'WindGustKmph': '23',
#                                    'WindGustMiles': '14',
#                                    'cloudcover': '0',
#                                    'humidity': '61',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.0',
#                                    'pressure': '1027',
#                                    'pressureInches': '31',
#                                    'tempC': '16',
#                                    'tempF': '61',
#                                    'time': '24',
#                                    'uvIndex': '4',
#                                    'visibility': '10',
#                                    'visibilityMiles': '6',
#                                    'weatherCode': '113',
#                                    'weatherDesc': [{'value': 'Sunny'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#                                    'winddir16Point': 'W',
#                                    'winddirDegree': '263',
#                                    'windspeedKmph': '14',
#                                    'windspeedMiles': '9'}],
#                        'maxtempC': '16',
#                        'maxtempF': '61',
#                        'mintempC': '11',
#                        'mintempF': '52',
#                        'sunHour': '11.1',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '4'}]}}
# {'data': {'request': [{'query': 'New York, United States of America',
#                        'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '0',
#                                       'moon_phase': 'New Moon',
#                                       'moonrise': '07:30 AM',
#                                       'moonset': '06:03 PM',
#                                       'sunrise': '07:29 AM',
#                                       'sunset': '05:50 PM'}],
#                        'avgtempC': '7',
#                        'avgtempF': '45',
#                        'date': '2013-11-03',
#                        'hourly': [{'DewPointC': '2',
#                                    'DewPointF': '36',
#                                    'FeelsLikeC': '4',
#                                    'FeelsLikeF': '40',
#                                    'HeatIndexC': '7',
#                                    'HeatIndexF': '45',
#                                    'WindChillC': '4',
#                                    'WindChillF': '40',
#                                    'WindGustKmph': '25',
#                                    'WindGustMiles': '15',
#                                    'cloudcover': '37',
#                                    'humidity': '72',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.9',
#                                    'pressure': '1019',
#                                    'pressureInches': '31',
#                                    'tempC': '10',
#                                    'tempF': '49',
#                                    'time': '24',
#                                    'uvIndex': '3',
#                                    'visibility': '10',
#                                    'visibilityMiles': '6',
#                                    'weatherCode': '113',
#                                    'weatherDesc': [{'value': 'Sunny'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#                                    'winddir16Point': 'WSW',
#                                    'winddirDegree': '254',
#                                    'windspeedKmph': '17',
#                                    'windspeedMiles': '11'}],
#                        'maxtempC': '10',
#                        'maxtempF': '49',
#                        'mintempC': '3',
#                        'mintempF': '37',
#                        'sunHour': '7.1',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '3'}]}}

# %%
print(feel_13_list)
# Out:
# ['33', '43', '47', '45', '55', '40']

# %%
majors_weather_dict = {
    "city": city_13_list,
    "feels_like_13": feel_13_list,
}
majors_13_weather_df = pd.DataFrame(majors_weather_dict)
majors_13_weather_df.head()
# Out:
#       city feels_like_13
# 0    Tokyo            33
# 1   Boston            43
# 2   London            47
# 3   Berlin            45
# 4  Chicago            55

# %%
city_14_list = []
feel_14_list = []


url = "https://api.worldweatheronline.com/premium/v1/past-weather.ashx"
params = {
    "key": "bc1fb38cb0ec446b83221156192908",  
    "tp": 24,
    "format": "json",    
}

for index, row in major_dates_df.iterrows():
 
    params['q'] = row['major']
    params['date'] = row['14 majors']
    
    response = requests.get(url, params=params).json()
    
    city_14_list.append(row['major'])
    feel_14_list.append((response['data']['weather'][0]['hourly'][0]['FeelsLikeF']))
    pprint(response)
# Out:
# {'data': {'request': [{'query': 'Tokyo, Japan', 'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '28',
#                                       'moon_phase': 'Last Quarter',
#                                       'moonrise': '12:32 AM',
#                                       'moonset': '11:04 AM',
#                                       'sunrise': '06:19 AM',
#                                       'sunset': '05:31 PM'}],
#                        'avgtempC': '3',
#                        'avgtempF': '38',
#                        'date': '2014-02-23',
#                        'hourly': [{'DewPointC': '-1',
#                                    'DewPointF': '31',
#                                    'FeelsLikeC': '1',
#                                    'FeelsLikeF': '34',
#                                    'HeatIndexC': '4',
#                                    'HeatIndexF': '39',
#                                    'WindChillC': '1',
#                                    'WindChillF': '34',
#                                    'WindGustKmph': '18',
#                                    'WindGustMiles': '11',
#                                    'cloudcover': '44',
#                                    'humidity': '71',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.0',
#                                    'pressure': '1028',
#                                    'pressureInches': '31',
#                                    'tempC': '7',
#                                    'tempF': '45',
#                                    'time': '24',
#                                    'uvIndex': '2',
#                                    'visibility': '10',
#                                    'visibilityMiles': '6',
#                                    'weatherCode': '116',
#                                    'weatherDesc': [{'value': 'Partly cloudy'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#                                    'winddir16Point': 'SSE',
#                                    'winddirDegree': '147',
#                                    'windspeedKmph': '13',
#                                    'windspeedMiles': '8'}],
#                        'maxtempC': '7',
#                        'maxtempF': '45',
#                        'mintempC': '0',
#                        'mintempF': '33',
#                        'sunHour': '5.7',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '2'}]}}
# {'data': {'request': [{'query': 'Boston, United States of America',
#                        'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '44',
#                                       'moon_phase': 'Last Quarter',
#                                       'moonrise': '01:02 AM',
#                                       'moonset': '11:15 AM',
#                                       'sunrise': '05:54 AM',
#                                       'sunset': '07:33 PM'}],
#                        'avgtempC': '10',
#                        'avgtempF': '49',
#                        'date': '2014-04-21',
#                        'hourly': [{'DewPointC': '3',
#                                    'DewPointF': '38',
#                                    'FeelsLikeC': '9',
#                                    'FeelsLikeF': '48',
#                                    'HeatIndexC': '10',
#                                    'HeatIndexF': '50',
#                                    'WindChillC': '9',
#                                    'WindChillF': '48',
#                                    'WindGustKmph': '19',
#                                    'WindGustMiles': '12',
#                                    'cloudcover': '17',
#                                    'humidity': '66',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.0',
#                                    'pressure': '1019',
#                                    'pressureInches': '31',
#                                    'tempC': '17',
#                                    'tempF': '63',
#                                    'time': '24',
#                                    'uvIndex': '3',
#                                    'visibility': '10',
#                                    'visibilityMiles': '6',
#                                    'weatherCode': '113',
#                                    'weatherDesc': [{'value': 'Sunny'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#                                    'winddir16Point': 'SSW',
#                                    'winddirDegree': '203',
#                                    'windspeedKmph': '12',
#                                    'windspeedMiles': '8'}],
#                        'maxtempC': '17',
#                        'maxtempF': '63',
#                        'mintempC': '2',
#                        'mintempF': '35',
#                        'sunHour': '13.8',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '3'}]}}
# {'data': {'request': [{'query': 'London, United Kingdom', 'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '96',
#                                       'moon_phase': 'Waxing Gibbous',
#                                       'moonrise': '06:06 PM',
#                                       'moonset': '05:14 AM',
#                                       'sunrise': '06:09 AM',
#                                       'sunset': '07:54 PM'}],
#                        'avgtempC': '10',
#                        'avgtempF': '50',
#                        'date': '2014-04-13',
#                        'hourly': [{'DewPointC': '7',
#                                    'DewPointF': '44',
#                                    'FeelsLikeC': '9',
#                                    'FeelsLikeF': '49',
#                                    'HeatIndexC': '11',
#                                    'HeatIndexF': '51',
#                                    'WindChillC': '9',
#                                    'WindChillF': '49',
#                                    'WindGustKmph': '20',
#                                    'WindGustMiles': '12',
#                                    'cloudcover': '35',
#                                    'humidity': '78',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.0',
#                                    'pressure': '1021',
#                                    'pressureInches': '31',
#                                    'tempC': '15',
#                                    'tempF': '59',
#                                    'time': '24',
#                                    'uvIndex': '3',
#                                    'visibility': '8',
#                                    'visibilityMiles': '4',
#                                    'weatherCode': '113',
#                                    'weatherDesc': [{'value': 'Sunny'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#                                    'winddir16Point': 'WNW',
#                                    'winddirDegree': '288',
#                                    'windspeedKmph': '13',
#                                    'windspeedMiles': '8'}],
#                        'maxtempC': '15',
#                        'maxtempF': '59',
#                        'mintempC': '6',
#                        'mintempF': '42',
#                        'sunHour': '11.6',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '3'}]}}
# {'data': {'request': [{'query': 'Berlin, Germany', 'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '27',
#                                       'moon_phase': 'Waxing Crescent',
#                                       'moonrise': '11:30 AM',
#                                       'moonset': '08:50 PM',
#                                       'sunrise': '07:02 AM',
#                                       'sunset': '06:51 PM'}],
#                        'avgtempC': '14',
#                        'avgtempF': '57',
#                        'date': '2014-09-28',
#                        'hourly': [{'DewPointC': '9',
#                                    'DewPointF': '48',
#                                    'FeelsLikeC': '15',
#                                    'FeelsLikeF': '59',
#                                    'HeatIndexC': '15',
#                                    'HeatIndexF': '59',
#                                    'WindChillC': '15',
#                                    'WindChillF': '59',
#                                    'WindGustKmph': '12',
#                                    'WindGustMiles': '8',
#                                    'cloudcover': '25',
#                                    'humidity': '69',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.0',
#                                    'pressure': '1026',
#                                    'pressureInches': '31',
#                                    'tempC': '20',
#                                    'tempF': '68',
#                                    'time': '24',
#                                    'uvIndex': '4',
#                                    'visibility': '10',
#                                    'visibilityMiles': '6',
#                                    'weatherCode': '113',
#                                    'weatherDesc': [{'value': 'Sunny'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#                                    'winddir16Point': 'SSW',
#                                    'winddirDegree': '205',
#                                    'windspeedKmph': '8',
#                                    'windspeedMiles': '5'}],
#                        'maxtempC': '20',
#                        'maxtempF': '68',
#                        'mintempC': '8',
#                        'mintempF': '47',
#                        'sunHour': '10.1',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '4'}]}}
# {'data': {'request': [{'query': 'Chicago, United States of America',
#                        'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '72',
#                                       'moon_phase': 'Waning Gibbous',
#                                       'moonrise': '09:29 PM',
#                                       'moonset': '11:24 AM',
#                                       'sunrise': '07:00 AM',
#                                       'sunset': '06:14 PM'}],
#                        'avgtempC': '12',
#                        'avgtempF': '53',
#                        'date': '2014-10-12',
#                        'hourly': [{'DewPointC': '7',
#                                    'DewPointF': '45',
#                                    'FeelsLikeC': '10',
#                                    'FeelsLikeF': '50',
#                                    'HeatIndexC': '12',
#                                    'HeatIndexF': '53',
#                                    'WindChillC': '10',
#                                    'WindChillF': '50',
#                                    'WindGustKmph': '28',
#                                    'WindGustMiles': '17',
#                                    'cloudcover': '31',
#                                    'humidity': '75',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.5',
#                                    'pressure': '1017',
#                                    'pressureInches': '31',
#                                    'tempC': '15',
#                                    'tempF': '60',
#                                    'time': '24',
#                                    'uvIndex': '4',
#                                    'visibility': '9',
#                                    'visibilityMiles': '5',
#                                    'weatherCode': '113',
#                                    'weatherDesc': [{'value': 'Sunny'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#                                    'winddir16Point': 'SE',
#                                    'winddirDegree': '136',
#                                    'windspeedKmph': '17',
#                                    'windspeedMiles': '10'}],
#                        'maxtempC': '15',
#                        'maxtempF': '60',
#                        'mintempC': '8',
#                        'mintempF': '46',
#                        'sunHour': '8.6',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '4'}]}}
# {'data': {'request': [{'query': 'New York, United States of America',
#                        'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '68',
#                                       'moon_phase': 'First Quarter',
#                                       'moonrise': '03:23 PM',
#                                       'moonset': '02:25 AM',
#                                       'sunrise': '07:28 AM',
#                                       'sunset': '05:51 PM'}],
#                        'avgtempC': '5',
#                        'avgtempF': '42',
#                        'date': '2014-11-02',
#                        'hourly': [{'DewPointC': '0',
#                                    'DewPointF': '33',
#                                    'FeelsLikeC': '1',
#                                    'FeelsLikeF': '33',
#                                    'HeatIndexC': '5',
#                                    'HeatIndexF': '42',
#                                    'WindChillC': '1',
#                                    'WindChillF': '33',
#                                    'WindGustKmph': '41',
#                                    'WindGustMiles': '26',
#                                    'cloudcover': '26',
#                                    'humidity': '71',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.2',
#                                    'pressure': '1012',
#                                    'pressureInches': '30',
#                                    'tempC': '8',
#                                    'tempF': '47',
#                                    'time': '24',
#                                    'uvIndex': '3',
#                                    'visibility': '9',
#                                    'visibilityMiles': '5',
#                                    'weatherCode': '113',
#                                    'weatherDesc': [{'value': 'Sunny'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#                                    'winddir16Point': 'NNW',
#                                    'winddirDegree': '332',
#                                    'windspeedKmph': '29',
#                                    'windspeedMiles': '18'}],
#                        'maxtempC': '8',
#                        'maxtempF': '47',
#                        'mintempC': '3',
#                        'mintempF': '37',
#                        'sunHour': '8.7',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '3'}]}}

# %%
majors_weather_dict = {
    "city": city_14_list,
    "feels_like_14": feel_14_list,
}
majors_14_weather_df = pd.DataFrame(majors_weather_dict)
majors_14_weather_df.head()
# Out:
#       city feels_like_14
# 0    Tokyo            34
# 1   Boston            48
# 2   London            49
# 3   Berlin            59
# 4  Chicago            50

# %%
city_15_list = []
feel_15_list = []


url = "https://api.worldweatheronline.com/premium/v1/past-weather.ashx"
params = {
    "key": "bc1fb38cb0ec446b83221156192908",  
    "tp": 24,
    "format": "json",    
}

for index, row in major_dates_df.iterrows():
 
    params['q'] = row['major']
    params['date'] = row['15 majors']
    
    response = requests.get(url, params=params).json()
    
    city_15_list.append(row['major'])
    feel_15_list.append((response['data']['weather'][0]['hourly'][0]['FeelsLikeF']))
    pprint(response)
# Out:
# {'data': {'request': [{'query': 'Tokyo, Japan', 'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '22',
#                                       'moon_phase': 'Waxing Crescent',
#                                       'moonrise': '08:15 AM',
#                                       'moonset': '09:21 PM',
#                                       'sunrise': '06:21 AM',
#                                       'sunset': '05:29 PM'}],
#                        'avgtempC': '8',
#                        'avgtempF': '46',
#                        'date': '2015-02-22',
#                        'hourly': [{'DewPointC': '5',
#                                    'DewPointF': '42',
#                                    'FeelsLikeC': '7',
#                                    'FeelsLikeF': '44',
#                                    'HeatIndexC': '8',
#                                    'HeatIndexF': '47',
#                                    'WindChillC': '7',
#                                    'WindChillF': '44',
#                                    'WindGustKmph': '14',
#                                    'WindGustMiles': '9',
#                                    'cloudcover': '97',
#                                    'humidity': '82',
#                                    'precipInches': '0.1',
#                                    'precipMM': '1.5',
#                                    'pressure': '1024',
#                                    'pressureInches': '31',
#                                    'tempC': '11',
#                                    'tempF': '52',
#                                    'time': '24',
#                                    'uvIndex': '2',
#                                    'visibility': '7',
#                                    'visibilityMiles': '4',
#                                    'weatherCode': '266',
#                                    'weatherDesc': [{'value': 'Light drizzle'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0017_cloudy_with_light_rain.png'}],
#                                    'winddir16Point': 'E',
#                                    'winddirDegree': '93',
#                                    'windspeedKmph': '9',
#                                    'windspeedMiles': '6'}],
#                        'maxtempC': '11',
#                        'maxtempF': '52',
#                        'mintempC': '6',
#                        'mintempF': '43',
#                        'sunHour': '4.2',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '2'}]}}
# {'data': {'request': [{'query': 'Boston, United States of America',
#                        'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '6',
#                                       'moon_phase': 'Waxing Crescent',
#                                       'moonrise': '07:21 AM',
#                                       'moonset': '09:51 PM',
#                                       'sunrise': '05:56 AM',
#                                       'sunset': '07:32 PM'}],
#                        'avgtempC': '7',
#                        'avgtempF': '45',
#                        'date': '2015-04-20',
#                        'hourly': [{'DewPointC': '6',
#                                    'DewPointF': '43',
#                                    'FeelsLikeC': '5',
#                                    'FeelsLikeF': '41',
#                                    'HeatIndexC': '8',
#                                    'HeatIndexF': '46',
#                                    'WindChillC': '5',
#                                    'WindChillF': '41',
#                                    'WindGustKmph': '28',
#                                    'WindGustMiles': '17',
#                                    'cloudcover': '86',
#                                    'humidity': '90',
#                                    'precipInches': '0.4',
#                                    'precipMM': '9.9',
#                                    'pressure': '1017',
#                                    'pressureInches': '31',
#                                    'tempC': '11',
#                                    'tempF': '53',
#                                    'time': '24',
#                                    'uvIndex': '2',
#                                    'visibility': '9',
#                                    'visibilityMiles': '5',
#                                    'weatherCode': '122',
#                                    'weatherDesc': [{'value': 'Overcast'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#                                    'winddir16Point': 'ESE',
#                                    'winddirDegree': '120',
#                                    'windspeedKmph': '18',
#                                    'windspeedMiles': '11'}],
#                        'maxtempC': '11',
#                        'maxtempF': '53',
#                        'mintempC': '4',
#                        'mintempF': '39',
#                        'sunHour': '8.6',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '2'}]}}
# {'data': {'request': [{'query': 'London, United Kingdom', 'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '52',
#                                       'moon_phase': 'First Quarter',
#                                       'moonrise': '12:26 PM',
#                                       'moonset': '02:28 AM',
#                                       'sunrise': '05:43 AM',
#                                       'sunset': '08:15 PM'}],
#                        'avgtempC': '9',
#                        'avgtempF': '48',
#                        'date': '2015-04-26',
#                        'hourly': [{'DewPointC': '7',
#                                    'DewPointF': '44',
#                                    'FeelsLikeC': '7',
#                                    'FeelsLikeF': '45',
#                                    'HeatIndexC': '9',
#                                    'HeatIndexF': '48',
#                                    'WindChillC': '7',
#                                    'WindChillF': '45',
#                                    'WindGustKmph': '18',
#                                    'WindGustMiles': '11',
#                                    'cloudcover': '76',
#                                    'humidity': '85',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.0',
#                                    'pressure': '1008',
#                                    'pressureInches': '30',
#                                    'tempC': '10',
#                                    'tempF': '50',
#                                    'time': '24',
#                                    'uvIndex': '2',
#                                    'visibility': '8',
#                                    'visibilityMiles': '4',
#                                    'weatherCode': '122',
#                                    'weatherDesc': [{'value': 'Overcast'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#                                    'winddir16Point': 'E',
#                                    'winddirDegree': '100',
#                                    'windspeedKmph': '12',
#                                    'windspeedMiles': '8'}],
#                        'maxtempC': '10',
#                        'maxtempF': '50',
#                        'mintempC': '5',
#                        'mintempF': '42',
#                        'sunHour': '10.3',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '2'}]}}
# {'data': {'request': [{'query': 'Berlin, Germany', 'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '99',
#                                       'moon_phase': 'Full Moon',
#                                       'moonrise': '06:38 PM',
#                                       'moonset': '05:49 AM',
#                                       'sunrise': '07:00 AM',
#                                       'sunset': '06:54 PM'}],
#                        'avgtempC': '12',
#                        'avgtempF': '53',
#                        'date': '2015-09-27',
#                        'hourly': [{'DewPointC': '8',
#                                    'DewPointF': '46',
#                                    'FeelsLikeC': '13',
#                                    'FeelsLikeF': '55',
#                                    'HeatIndexC': '13',
#                                    'HeatIndexF': '56',
#                                    'WindChillC': '13',
#                                    'WindChillF': '55',
#                                    'WindGustKmph': '13',
#                                    'WindGustMiles': '8',
#                                    'cloudcover': '23',
#                                    'humidity': '72',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.0',
#                                    'pressure': '1031',
#                                    'pressureInches': '31',
#                                    'tempC': '17',
#                                    'tempF': '63',
#                                    'time': '24',
#                                    'uvIndex': '4',
#                                    'visibility': '9',
#                                    'visibilityMiles': '5',
#                                    'weatherCode': '113',
#                                    'weatherDesc': [{'value': 'Sunny'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#                                    'winddir16Point': 'SW',
#                                    'winddirDegree': '214',
#                                    'windspeedKmph': '9',
#                                    'windspeedMiles': '5'}],
#                        'maxtempC': '17',
#                        'maxtempF': '63',
#                        'mintempC': '7',
#                        'mintempF': '45',
#                        'sunHour': '8.7',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '4'}]}}
# {'data': {'request': [{'query': 'Chicago, United States of America',
#                        'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '2',
#                                       'moon_phase': 'Waning Crescent',
#                                       'moonrise': '05:37 AM',
#                                       'moonset': '05:47 PM',
#                                       'sunrise': '06:58 AM',
#                                       'sunset': '06:16 PM'}],
#                        'avgtempC': '17',
#                        'avgtempF': '62',
#                        'date': '2015-10-11',
#                        'hourly': [{'DewPointC': '9',
#                                    'DewPointF': '48',
#                                    'FeelsLikeC': '16',
#                                    'FeelsLikeF': '60',
#                                    'HeatIndexC': '17',
#                                    'HeatIndexF': '63',
#                                    'WindChillC': '16',
#                                    'WindChillF': '60',
#                                    'WindGustKmph': '49',
#                                    'WindGustMiles': '30',
#                                    'cloudcover': '2',
#                                    'humidity': '60',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.0',
#                                    'pressure': '1009',
#                                    'pressureInches': '30',
#                                    'tempC': '22',
#                                    'tempF': '72',
#                                    'time': '24',
#                                    'uvIndex': '5',
#                                    'visibility': '10',
#                                    'visibilityMiles': '6',
#                                    'weatherCode': '113',
#                                    'weatherDesc': [{'value': 'Sunny'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#                                    'winddir16Point': 'SSW',
#                                    'winddirDegree': '211',
#                                    'windspeedKmph': '27',
#                                    'windspeedMiles': '17'}],
#                        'maxtempC': '22',
#                        'maxtempF': '72',
#                        'mintempC': '12',
#                        'mintempF': '53',
#                        'sunHour': '11.6',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '5'}]}}
# {'data': {'request': [{'query': 'New York, United States of America',
#                        'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '59',
#                                       'moon_phase': 'Waning Gibbous',
#                                       'moonrise': '10:49 PM',
#                                       'moonset': '12:28 PM',
#                                       'sunrise': '07:26 AM',
#                                       'sunset': '05:53 PM'}],
#                        'avgtempC': '13',
#                        'avgtempF': '56',
#                        'date': '2015-11-01',
#                        'hourly': [{'DewPointC': '10',
#                                    'DewPointF': '50',
#                                    'FeelsLikeC': '13',
#                                    'FeelsLikeF': '55',
#                                    'HeatIndexC': '14',
#                                    'HeatIndexF': '57',
#                                    'WindChillC': '13',
#                                    'WindChillF': '55',
#                                    'WindGustKmph': '26',
#                                    'WindGustMiles': '16',
#                                    'cloudcover': '50',
#                                    'humidity': '80',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.1',
#                                    'pressure': '1015',
#                                    'pressureInches': '30',
#                                    'tempC': '17',
#                                    'tempF': '62',
#                                    'time': '24',
#                                    'uvIndex': '3',
#                                    'visibility': '10',
#                                    'visibilityMiles': '6',
#                                    'weatherCode': '119',
#                                    'weatherDesc': [{'value': 'Cloudy'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0003_white_cloud.png'}],
#                                    'winddir16Point': 'SW',
#                                    'winddirDegree': '229',
#                                    'windspeedKmph': '16',
#                                    'windspeedMiles': '10'}],
#                        'maxtempC': '17',
#                        'maxtempF': '62',
#                        'mintempC': '10',
#                        'mintempF': '51',
#                        'sunHour': '7.1',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '3'}]}}

# %%
majors_weather_dict = {
    "city": city_15_list,
    "feels_like_15": feel_15_list,
}
majors_15_weather_df = pd.DataFrame(majors_weather_dict)
majors_15_weather_df.head()
# Out:
#       city feels_like_15
# 0    Tokyo            44
# 1   Boston            41
# 2   London            45
# 3   Berlin            55
# 4  Chicago            60

# %%
city_16_list = []
feel_16_list = []


url = "https://api.worldweatheronline.com/premium/v1/past-weather.ashx"
params = {
    "key": "bc1fb38cb0ec446b83221156192908",  
    "tp": 24,
    "format": "json",    
}

for index, row in major_dates_df.iterrows():
 
    params['q'] = row['major']
    params['date'] = row['16 majors']
    
    response = requests.get(url, params=params).json()

    city_16_list.append(row['major'])
    feel_16_list.append((response['data']['weather'][0]['hourly'][0]['FeelsLikeF']))
    pprint(response)
# Out:
# {'data': {'request': [{'query': 'Tokyo, Japan', 'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '53',
#                                       'moon_phase': 'Waning Gibbous',
#                                       'moonrise': '10:32 PM',
#                                       'moonset': '09:03 AM',
#                                       'sunrise': '06:14 AM',
#                                       'sunset': '05:35 PM'}],
#                        'avgtempC': '8',
#                        'avgtempF': '46',
#                        'date': '2016-02-28',
#                        'hourly': [{'DewPointC': '2',
#                                    'DewPointF': '36',
#                                    'FeelsLikeC': '7',
#                                    'FeelsLikeF': '44',
#                                    'HeatIndexC': '9',
#                                    'HeatIndexF': '48',
#                                    'WindChillC': '7',
#                                    'WindChillF': '44',
#                                    'WindGustKmph': '23',
#                                    'WindGustMiles': '14',
#                                    'cloudcover': '31',
#                                    'humidity': '63',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.1',
#                                    'pressure': '1025',
#                                    'pressureInches': '31',
#                                    'tempC': '11',
#                                    'tempF': '52',
#                                    'time': '24',
#                                    'uvIndex': '3',
#                                    'visibility': '10',
#                                    'visibilityMiles': '6',
#                                    'weatherCode': '113',
#                                    'weatherDesc': [{'value': 'Sunny'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#                                    'winddir16Point': 'SE',
#                                    'winddirDegree': '132',
#                                    'windspeedKmph': '16',
#                                    'windspeedMiles': '10'}],
#                        'maxtempC': '11',
#                        'maxtempF': '52',
#                        'mintempC': '4',
#                        'mintempF': '39',
#                        'sunHour': '8.7',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '3'}]}}
# {'data': {'request': [{'query': 'Boston, United States of America',
#                        'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '79',
#                                       'moon_phase': 'Waxing Gibbous',
#                                       'moonrise': '04:17 PM',
#                                       'moonset': '04:24 AM',
#                                       'sunrise': '05:58 AM',
#                                       'sunset': '07:30 PM'}],
#                        'avgtempC': '9',
#                        'avgtempF': '47',
#                        'date': '2016-04-18',
#                        'hourly': [{'DewPointC': '3',
#                                    'DewPointF': '37',
#                                    'FeelsLikeC': '7',
#                                    'FeelsLikeF': '45',
#                                    'HeatIndexC': '9',
#                                    'HeatIndexF': '48',
#                                    'WindChillC': '7',
#                                    'WindChillF': '45',
#                                    'WindGustKmph': '17',
#                                    'WindGustMiles': '11',
#                                    'cloudcover': '60',
#                                    'humidity': '66',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.2',
#                                    'pressure': '1018',
#                                    'pressureInches': '31',
#                                    'tempC': '12',
#                                    'tempF': '54',
#                                    'time': '24',
#                                    'uvIndex': '3',
#                                    'visibility': '10',
#                                    'visibilityMiles': '6',
#                                    'weatherCode': '116',
#                                    'weatherDesc': [{'value': 'Partly cloudy'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#                                    'winddir16Point': 'S',
#                                    'winddirDegree': '176',
#                                    'windspeedKmph': '12',
#                                    'windspeedMiles': '7'}],
#                        'maxtempC': '12',
#                        'maxtempF': '54',
#                        'mintempC': '5',
#                        'mintempF': '42',
#                        'sunHour': '12.1',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '3'}]}}
# {'data': {'request': [{'query': 'London, United Kingdom', 'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '76',
#                                       'moon_phase': 'Waning Gibbous',
#                                       'moonrise': '10:27 PM',
#                                       'moonset': '07:13 AM',
#                                       'sunrise': '05:45 AM',
#                                       'sunset': '08:13 PM'}],
#                        'avgtempC': '6',
#                        'avgtempF': '43',
#                        'date': '2016-04-24',
#                        'hourly': [{'DewPointC': '2',
#                                    'DewPointF': '35',
#                                    'FeelsLikeC': '3',
#                                    'FeelsLikeF': '38',
#                                    'HeatIndexC': '6',
#                                    'HeatIndexF': '43',
#                                    'WindChillC': '3',
#                                    'WindChillF': '38',
#                                    'WindGustKmph': '21',
#                                    'WindGustMiles': '13',
#                                    'cloudcover': '80',
#                                    'humidity': '74',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.3',
#                                    'pressure': '1020',
#                                    'pressureInches': '31',
#                                    'tempC': '9',
#                                    'tempF': '48',
#                                    'time': '24',
#                                    'uvIndex': '2',
#                                    'visibility': '10',
#                                    'visibilityMiles': '6',
#                                    'weatherCode': '122',
#                                    'weatherDesc': [{'value': 'Overcast'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#                                    'winddir16Point': 'W',
#                                    'winddirDegree': '280',
#                                    'windspeedKmph': '15',
#                                    'windspeedMiles': '10'}],
#                        'maxtempC': '9',
#                        'maxtempF': '48',
#                        'mintempC': '3',
#                        'mintempF': '37',
#                        'sunHour': '9.2',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '2'}]}}
# {'data': {'request': [{'query': 'Berlin, Germany', 'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '28',
#                                       'moon_phase': 'Last Quarter',
#                                       'moonrise': '12:43 AM',
#                                       'moonset': '04:24 PM',
#                                       'sunrise': '06:58 AM',
#                                       'sunset': '06:57 PM'}],
#                        'avgtempC': '15',
#                        'avgtempF': '60',
#                        'date': '2016-09-25',
#                        'hourly': [{'DewPointC': '9',
#                                    'DewPointF': '47',
#                                    'FeelsLikeC': '16',
#                                    'FeelsLikeF': '60',
#                                    'HeatIndexC': '16',
#                                    'HeatIndexF': '62',
#                                    'WindChillC': '16',
#                                    'WindChillF': '60',
#                                    'WindGustKmph': '16',
#                                    'WindGustMiles': '10',
#                                    'cloudcover': '40',
#                                    'humidity': '64',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.0',
#                                    'pressure': '1022',
#                                    'pressureInches': '31',
#                                    'tempC': '22',
#                                    'tempF': '71',
#                                    'time': '24',
#                                    'uvIndex': '4',
#                                    'visibility': '10',
#                                    'visibilityMiles': '6',
#                                    'weatherCode': '119',
#                                    'weatherDesc': [{'value': 'Cloudy'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0003_white_cloud.png'}],
#                                    'winddir16Point': 'SE',
#                                    'winddirDegree': '134',
#                                    'windspeedKmph': '10',
#                                    'windspeedMiles': '6'}],
#                        'maxtempC': '22',
#                        'maxtempF': '71',
#                        'mintempC': '10',
#                        'mintempF': '51',
#                        'sunHour': '8.8',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '4'}]}}
# {'data': {'request': [{'query': 'Chicago, United States of America',
#                        'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '53',
#                                       'moon_phase': 'First Quarter',
#                                       'moonrise': '02:22 PM',
#                                       'moonset': 'No moonset',
#                                       'sunrise': '06:57 AM',
#                                       'sunset': '06:18 PM'}],
#                        'avgtempC': '13',
#                        'avgtempF': '56',
#                        'date': '2016-10-09',
#                        'hourly': [{'DewPointC': '8',
#                                    'DewPointF': '47',
#                                    'FeelsLikeC': '12',
#                                    'FeelsLikeF': '54',
#                                    'HeatIndexC': '13',
#                                    'HeatIndexF': '56',
#                                    'WindChillC': '12',
#                                    'WindChillF': '54',
#                                    'WindGustKmph': '25',
#                                    'WindGustMiles': '15',
#                                    'cloudcover': '13',
#                                    'humidity': '71',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.0',
#                                    'pressure': '1027',
#                                    'pressureInches': '31',
#                                    'tempC': '15',
#                                    'tempF': '60',
#                                    'time': '24',
#                                    'uvIndex': '4',
#                                    'visibility': '10',
#                                    'visibilityMiles': '6',
#                                    'weatherCode': '113',
#                                    'weatherDesc': [{'value': 'Sunny'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#                                    'winddir16Point': 'E',
#                                    'winddirDegree': '94',
#                                    'windspeedKmph': '16',
#                                    'windspeedMiles': '10'}],
#                        'maxtempC': '15',
#                        'maxtempF': '60',
#                        'mintempC': '10',
#                        'mintempF': '50',
#                        'sunHour': '11.6',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '4'}]}}
# {'data': {'request': [{'query': 'New York, United States of America',
#                        'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '43',
#                                       'moon_phase': 'First Quarter',
#                                       'moonrise': '01:04 PM',
#                                       'moonset': '11:27 PM',
#                                       'sunrise': '07:33 AM',
#                                       'sunset': '05:46 PM'}],
#                        'avgtempC': '11',
#                        'avgtempF': '51',
#                        'date': '2016-11-06',
#                        'hourly': [{'DewPointC': '5',
#                                    'DewPointF': '40',
#                                    'FeelsLikeC': '8',
#                                    'FeelsLikeF': '47',
#                                    'HeatIndexC': '11',
#                                    'HeatIndexF': '51',
#                                    'WindChillC': '8',
#                                    'WindChillF': '47',
#                                    'WindGustKmph': '32',
#                                    'WindGustMiles': '20',
#                                    'cloudcover': '15',
#                                    'humidity': '67',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.0',
#                                    'pressure': '1024',
#                                    'pressureInches': '31',
#                                    'tempC': '14',
#                                    'tempF': '56',
#                                    'time': '24',
#                                    'uvIndex': '4',
#                                    'visibility': '10',
#                                    'visibilityMiles': '6',
#                                    'weatherCode': '113',
#                                    'weatherDesc': [{'value': 'Sunny'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#                                    'winddir16Point': 'SSW',
#                                    'winddirDegree': '205',
#                                    'windspeedKmph': '21',
#                                    'windspeedMiles': '13'}],
#                        'maxtempC': '14',
#                        'maxtempF': '56',
#                        'mintempC': '7',
#                        'mintempF': '45',
#                        'sunHour': '8.7',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '4'}]}}

# %%
majors_weather_dict = {
    "city": city_16_list,
    "feels_like_16": feel_16_list,
}
majors_16_weather_df = pd.DataFrame(majors_weather_dict)
majors_16_weather_df.head()
# Out:
#       city feels_like_16
# 0    Tokyo            44
# 1   Boston            45
# 2   London            38
# 3   Berlin            60
# 4  Chicago            54

# %%
city_17_list = []
feel_17_list = []

url = "https://api.worldweatheronline.com/premium/v1/past-weather.ashx"
params = {
    "key": "bc1fb38cb0ec446b83221156192908",  
    "tp": 24,
    "format": "json",    
}

for index, row in major_dates_df.iterrows():
 
    params['q'] = row['major']
    params['date'] = row['17 majors']
    
    response = requests.get(url, params=params).json()

    city_17_list.append(row['major'])
    feel_17_list.append((response['data']['weather'][0]['hourly'][0]['FeelsLikeF']))
    pprint(response)
# Out:
# {'data': {'request': [{'query': 'Tokyo, Japan', 'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '12',
#                                       'moon_phase': 'Waxing Crescent',
#                                       'moonrise': '07:09 AM',
#                                       'moonset': '07:20 PM',
#                                       'sunrise': '06:13 AM',
#                                       'sunset': '05:35 PM'}],
#                        'avgtempC': '5',
#                        'avgtempF': '41',
#                        'date': '2017-02-28',
#                        'hourly': [{'DewPointC': '-1',
#                                    'DewPointF': '31',
#                                    'FeelsLikeC': '2',
#                                    'FeelsLikeF': '36',
#                                    'HeatIndexC': '5',
#                                    'HeatIndexF': '42',
#                                    'WindChillC': '2',
#                                    'WindChillF': '36',
#                                    'WindGustKmph': '20',
#                                    'WindGustMiles': '12',
#                                    'cloudcover': '7',
#                                    'humidity': '65',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.0',
#                                    'pressure': '1025',
#                                    'pressureInches': '31',
#                                    'tempC': '8',
#                                    'tempF': '47',
#                                    'time': '24',
#                                    'uvIndex': '2',
#                                    'visibility': '10',
#                                    'visibilityMiles': '6',
#                                    'weatherCode': '113',
#                                    'weatherDesc': [{'value': 'Sunny'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#                                    'winddir16Point': 'NE',
#                                    'winddirDegree': '41',
#                                    'windspeedKmph': '14',
#                                    'windspeedMiles': '9'}],
#                        'maxtempC': '8',
#                        'maxtempF': '47',
#                        'mintempC': '1',
#                        'mintempF': '34',
#                        'sunHour': '8.7',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '2'}]}}
# {'data': {'request': [{'query': 'Boston, United States of America',
#                        'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '48',
#                                       'moon_phase': 'Waning Gibbous',
#                                       'moonrise': '12:28 AM',
#                                       'moonset': '10:18 AM',
#                                       'sunrise': '06:00 AM',
#                                       'sunset': '07:29 PM'}],
#                        'avgtempC': '17',
#                        'avgtempF': '63',
#                        'date': '2017-04-17',
#                        'hourly': [{'DewPointC': '8',
#                                    'DewPointF': '47',
#                                    'FeelsLikeC': '18',
#                                    'FeelsLikeF': '64',
#                                    'HeatIndexC': '18',
#                                    'HeatIndexF': '65',
#                                    'WindChillC': '18',
#                                    'WindChillF': '64',
#                                    'WindGustKmph': '19',
#                                    'WindGustMiles': '12',
#                                    'cloudcover': '16',
#                                    'humidity': '58',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.0',
#                                    'pressure': '1012',
#                                    'pressureInches': '30',
#                                    'tempC': '21',
#                                    'tempF': '70',
#                                    'time': '24',
#                                    'uvIndex': '5',
#                                    'visibility': '10',
#                                    'visibilityMiles': '6',
#                                    'weatherCode': '113',
#                                    'weatherDesc': [{'value': 'Sunny'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#                                    'winddir16Point': 'WSW',
#                                    'winddirDegree': '248',
#                                    'windspeedKmph': '14',
#                                    'windspeedMiles': '9'}],
#                        'maxtempC': '21',
#                        'maxtempF': '70',
#                        'mintempC': '11',
#                        'mintempF': '51',
#                        'sunHour': '13.3',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '5'}]}}
# {'data': {'request': [{'query': 'London, United Kingdom', 'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '3',
#                                       'moon_phase': 'Waning Crescent',
#                                       'moonrise': '04:44 AM',
#                                       'moonset': '04:15 PM',
#                                       'sunrise': '05:48 AM',
#                                       'sunset': '08:11 PM'}],
#                        'avgtempC': '9',
#                        'avgtempF': '49',
#                        'date': '2017-04-23',
#                        'hourly': [{'DewPointC': '7',
#                                    'DewPointF': '45',
#                                    'FeelsLikeC': '8',
#                                    'FeelsLikeF': '47',
#                                    'HeatIndexC': '10',
#                                    'HeatIndexF': '50',
#                                    'WindChillC': '8',
#                                    'WindChillF': '47',
#                                    'WindGustKmph': '15',
#                                    'WindGustMiles': '9',
#                                    'cloudcover': '83',
#                                    'humidity': '83',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.1',
#                                    'pressure': '1026',
#                                    'pressureInches': '31',
#                                    'tempC': '13',
#                                    'tempF': '55',
#                                    'time': '24',
#                                    'uvIndex': '2',
#                                    'visibility': '10',
#                                    'visibilityMiles': '6',
#                                    'weatherCode': '122',
#                                    'weatherDesc': [{'value': 'Overcast'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#                                    'winddir16Point': 'S',
#                                    'winddirDegree': '178',
#                                    'windspeedKmph': '10',
#                                    'windspeedMiles': '6'}],
#                        'maxtempC': '13',
#                        'maxtempF': '55',
#                        'mintempC': '6',
#                        'mintempF': '42',
#                        'sunHour': '9.1',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '2'}]}}
# {'data': {'request': [{'query': 'Berlin, Germany', 'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '22',
#                                       'moon_phase': 'Waxing Crescent',
#                                       'moonrise': '11:21 AM',
#                                       'moonset': '09:12 PM',
#                                       'sunrise': '06:56 AM',
#                                       'sunset': '07:00 PM'}],
#                        'avgtempC': '15',
#                        'avgtempF': '59',
#                        'date': '2017-09-24',
#                        'hourly': [{'DewPointC': '13',
#                                    'DewPointF': '55',
#                                    'FeelsLikeC': '15',
#                                    'FeelsLikeF': '59',
#                                    'HeatIndexC': '15',
#                                    'HeatIndexF': '59',
#                                    'WindChillC': '15',
#                                    'WindChillF': '59',
#                                    'WindGustKmph': '14',
#                                    'WindGustMiles': '9',
#                                    'cloudcover': '87',
#                                    'humidity': '85',
#                                    'precipInches': '0.2',
#                                    'precipMM': '5.6',
#                                    'pressure': '1022',
#                                    'pressureInches': '31',
#                                    'tempC': '18',
#                                    'tempF': '64',
#                                    'time': '24',
#                                    'uvIndex': '3',
#                                    'visibility': '9',
#                                    'visibilityMiles': '5',
#                                    'weatherCode': '119',
#                                    'weatherDesc': [{'value': 'Cloudy'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0003_white_cloud.png'}],
#                                    'winddir16Point': 'SE',
#                                    'winddirDegree': '139',
#                                    'windspeedKmph': '10',
#                                    'windspeedMiles': '6'}],
#                        'maxtempC': '18',
#                        'maxtempF': '64',
#                        'mintempC': '13',
#                        'mintempF': '55',
#                        'sunHour': '6.2',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '3'}]}}
# {'data': {'request': [{'query': 'Chicago, United States of America',
#                        'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '77',
#                                       'moon_phase': 'Waning Gibbous',
#                                       'moonrise': '08:39 PM',
#                                       'moonset': '10:00 AM',
#                                       'sunrise': '06:55 AM',
#                                       'sunset': '06:20 PM'}],
#                        'avgtempC': '19',
#                        'avgtempF': '66',
#                        'date': '2017-10-08',
#                        'hourly': [{'DewPointC': '12',
#                                    'DewPointF': '54',
#                                    'FeelsLikeC': '19',
#                                    'FeelsLikeF': '67',
#                                    'HeatIndexC': '20',
#                                    'HeatIndexF': '68',
#                                    'WindChillC': '19',
#                                    'WindChillF': '67',
#                                    'WindGustKmph': '22',
#                                    'WindGustMiles': '14',
#                                    'cloudcover': '0',
#                                    'humidity': '64',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.0',
#                                    'pressure': '1008',
#                                    'pressureInches': '30',
#                                    'tempC': '23',
#                                    'tempF': '74',
#                                    'time': '24',
#                                    'uvIndex': '5',
#                                    'visibility': '10',
#                                    'visibilityMiles': '6',
#                                    'weatherCode': '113',
#                                    'weatherDesc': [{'value': 'Sunny'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#                                    'winddir16Point': 'S',
#                                    'winddirDegree': '190',
#                                    'windspeedKmph': '16',
#                                    'windspeedMiles': '10'}],
#                        'maxtempC': '23',
#                        'maxtempF': '74',
#                        'mintempC': '15',
#                        'mintempF': '59',
#                        'sunHour': '11.6',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '5'}]}}
# {'data': {'request': [{'query': 'New York, United States of America',
#                        'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '84',
#                                       'moon_phase': 'Waxing Gibbous',
#                                       'moonrise': '07:23 PM',
#                                       'moonset': '08:53 AM',
#                                       'sunrise': '07:32 AM',
#                                       'sunset': '05:48 PM'}],
#                        'avgtempC': '14',
#                        'avgtempF': '58',
#                        'date': '2017-11-05',
#                        'hourly': [{'DewPointC': '12',
#                                    'DewPointF': '54',
#                                    'FeelsLikeC': '14',
#                                    'FeelsLikeF': '57',
#                                    'HeatIndexC': '14',
#                                    'HeatIndexF': '58',
#                                    'WindChillC': '14',
#                                    'WindChillF': '57',
#                                    'WindGustKmph': '19',
#                                    'WindGustMiles': '12',
#                                    'cloudcover': '100',
#                                    'humidity': '86',
#                                    'precipInches': '0.1',
#                                    'precipMM': '3.1',
#                                    'pressure': '1023',
#                                    'pressureInches': '31',
#                                    'tempC': '16',
#                                    'tempF': '60',
#                                    'time': '24',
#                                    'uvIndex': '3',
#                                    'visibility': '6',
#                                    'visibilityMiles': '3',
#                                    'weatherCode': '122',
#                                    'weatherDesc': [{'value': 'Overcast'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#                                    'winddir16Point': 'ESE',
#                                    'winddirDegree': '119',
#                                    'windspeedKmph': '13',
#                                    'windspeedMiles': '8'}],
#                        'maxtempC': '16',
#                        'maxtempF': '60',
#                        'mintempC': '13',
#                        'mintempF': '55',
#                        'sunHour': '3.8',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '3'}]}}

# %%
majors_weather_dict = {
    "city": city_17_list,
    "feels_like_17": feel_17_list,
}
majors_17_weather_df = pd.DataFrame(majors_weather_dict)
majors_17_weather_df.head()
# Out:
#       city feels_like_17
# 0    Tokyo            36
# 1   Boston            64
# 2   London            47
# 3   Berlin            59
# 4  Chicago            67

# %%
city_18_list = []
feel_18_list = []

url = "https://api.worldweatheronline.com/premium/v1/past-weather.ashx"
params = {
    "key": "bc1fb38cb0ec446b83221156192908",  
    "tp": 24,
    "format": "json",    
}

for index, row in major_dates_df.iterrows():
 
    params['q'] = row['major']
    params['date'] = row['18 majors']
    
    response = requests.get(url, params=params).json()

    city_18_list.append(row['major'])
    feel_18_list.append((response['data']['weather'][0]['hourly'][0]['FeelsLikeF']))
    pprint(response)
# Out:
# {'data': {'request': [{'query': 'Tokyo, Japan', 'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '70',
#                                       'moon_phase': 'Waxing Gibbous',
#                                       'moonrise': '12:23 PM',
#                                       'moonset': '01:55 AM',
#                                       'sunrise': '06:17 AM',
#                                       'sunset': '05:32 PM'}],
#                        'avgtempC': '7',
#                        'avgtempF': '45',
#                        'date': '2018-02-25',
#                        'hourly': [{'DewPointC': '-3',
#                                    'DewPointF': '26',
#                                    'FeelsLikeC': '5',
#                                    'FeelsLikeF': '42',
#                                    'HeatIndexC': '8',
#                                    'HeatIndexF': '46',
#                                    'WindChillC': '5',
#                                    'WindChillF': '42',
#                                    'WindGustKmph': '16',
#                                    'WindGustMiles': '10',
#                                    'cloudcover': '64',
#                                    'humidity': '46',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.0',
#                                    'pressure': '1025',
#                                    'pressureInches': '31',
#                                    'tempC': '9',
#                                    'tempF': '49',
#                                    'time': '24',
#                                    'uvIndex': '2',
#                                    'visibility': '10',
#                                    'visibilityMiles': '6',
#                                    'weatherCode': '122',
#                                    'weatherDesc': [{'value': 'Overcast'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#                                    'winddir16Point': 'ENE',
#                                    'winddirDegree': '59',
#                                    'windspeedKmph': '13',
#                                    'windspeedMiles': '8'}],
#                        'maxtempC': '9',
#                        'maxtempF': '49',
#                        'mintempC': '6',
#                        'mintempF': '42',
#                        'sunHour': '4.2',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '2'}]}}
# {'data': {'request': [{'query': 'Boston, United States of America',
#                        'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '1',
#                                       'moon_phase': 'Waxing Crescent',
#                                       'moonrise': '06:43 AM',
#                                       'moonset': '08:11 PM',
#                                       'sunrise': '06:02 AM',
#                                       'sunset': '07:27 PM'}],
#                        'avgtempC': '7',
#                        'avgtempF': '44',
#                        'date': '2018-04-16',
#                        'hourly': [{'DewPointC': '5',
#                                    'DewPointF': '41',
#                                    'FeelsLikeC': '3',
#                                    'FeelsLikeF': '38',
#                                    'HeatIndexC': '7',
#                                    'HeatIndexF': '44',
#                                    'WindChillC': '3',
#                                    'WindChillF': '38',
#                                    'WindGustKmph': '35',
#                                    'WindGustMiles': '22',
#                                    'cloudcover': '92',
#                                    'humidity': '90',
#                                    'precipInches': '0.8',
#                                    'precipMM': '19.2',
#                                    'pressure': '1014',
#                                    'pressureInches': '30',
#                                    'tempC': '13',
#                                    'tempF': '55',
#                                    'time': '24',
#                                    'uvIndex': '2',
#                                    'visibility': '8',
#                                    'visibilityMiles': '4',
#                                    'weatherCode': '122',
#                                    'weatherDesc': [{'value': 'Overcast'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#                                    'winddir16Point': 'ESE',
#                                    'winddirDegree': '105',
#                                    'windspeedKmph': '23',
#                                    'windspeedMiles': '14'}],
#                        'maxtempC': '13',
#                        'maxtempF': '55',
#                        'mintempC': '2',
#                        'mintempF': '36',
#                        'sunHour': '6.6',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '2'}]}}
# {'data': {'request': [{'query': 'London, United Kingdom', 'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '47',
#                                       'moon_phase': 'First Quarter',
#                                       'moonrise': '11:03 AM',
#                                       'moonset': '02:17 AM',
#                                       'sunrise': '05:50 AM',
#                                       'sunset': '08:09 PM'}],
#                        'avgtempC': '18',
#                        'avgtempF': '65',
#                        'date': '2018-04-22',
#                        'hourly': [{'DewPointC': '10',
#                                    'DewPointF': '50',
#                                    'FeelsLikeC': '19',
#                                    'FeelsLikeF': '65',
#                                    'HeatIndexC': '19',
#                                    'HeatIndexF': '66',
#                                    'WindChillC': '19',
#                                    'WindChillF': '65',
#                                    'WindGustKmph': '18',
#                                    'WindGustMiles': '11',
#                                    'cloudcover': '25',
#                                    'humidity': '59',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.0',
#                                    'pressure': '1011',
#                                    'pressureInches': '30',
#                                    'tempC': '23',
#                                    'tempF': '73',
#                                    'time': '24',
#                                    'uvIndex': '5',
#                                    'visibility': '10',
#                                    'visibilityMiles': '6',
#                                    'weatherCode': '113',
#                                    'weatherDesc': [{'value': 'Sunny'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#                                    'winddir16Point': 'SSW',
#                                    'winddirDegree': '211',
#                                    'windspeedKmph': '14',
#                                    'windspeedMiles': '9'}],
#                        'maxtempC': '23',
#                        'maxtempF': '73',
#                        'mintempC': '14',
#                        'mintempF': '58',
#                        'sunHour': '13.4',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '5'}]}}
# {'data': {'request': [{'query': 'Berlin, Germany', 'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '42',
#                                       'moon_phase': 'First Quarter',
#                                       'moonrise': '02:25 PM',
#                                       'moonset': '11:00 PM',
#                                       'sunrise': '06:42 AM',
#                                       'sunset': '07:20 PM'}],
#                        'avgtempC': '17',
#                        'avgtempF': '63',
#                        'date': '2018-09-16',
#                        'hourly': [{'DewPointC': '10',
#                                    'DewPointF': '49',
#                                    'FeelsLikeC': '18',
#                                    'FeelsLikeF': '65',
#                                    'HeatIndexC': '18',
#                                    'HeatIndexF': '65',
#                                    'WindChillC': '18',
#                                    'WindChillF': '65',
#                                    'WindGustKmph': '9',
#                                    'WindGustMiles': '6',
#                                    'cloudcover': '43',
#                                    'humidity': '60',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.0',
#                                    'pressure': '1024',
#                                    'pressureInches': '31',
#                                    'tempC': '22',
#                                    'tempF': '71',
#                                    'time': '24',
#                                    'uvIndex': '5',
#                                    'visibility': '10',
#                                    'visibilityMiles': '6',
#                                    'weatherCode': '116',
#                                    'weatherDesc': [{'value': 'Partly cloudy'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#                                    'winddir16Point': 'SSW',
#                                    'winddirDegree': '206',
#                                    'windspeedKmph': '7',
#                                    'windspeedMiles': '4'}],
#                        'maxtempC': '22',
#                        'maxtempF': '71',
#                        'mintempC': '13',
#                        'mintempF': '56',
#                        'sunHour': '10.3',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '5'}]}}
# {'data': {'request': [{'query': 'Chicago, United States of America',
#                        'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '22',
#                                       'moon_phase': 'Waxing Crescent',
#                                       'moonrise': '11:37 AM',
#                                       'moonset': '09:28 PM',
#                                       'sunrise': '07:01 AM',
#                                       'sunset': '06:12 PM'}],
#                        'avgtempC': '7',
#                        'avgtempF': '45',
#                        'date': '2018-10-13',
#                        'hourly': [{'DewPointC': '0',
#                                    'DewPointF': '32',
#                                    'FeelsLikeC': '5',
#                                    'FeelsLikeF': '40',
#                                    'HeatIndexC': '7',
#                                    'HeatIndexF': '45',
#                                    'WindChillC': '5',
#                                    'WindChillF': '40',
#                                    'WindGustKmph': '19',
#                                    'WindGustMiles': '12',
#                                    'cloudcover': '5',
#                                    'humidity': '60',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.0',
#                                    'pressure': '1017',
#                                    'pressureInches': '31',
#                                    'tempC': '11',
#                                    'tempF': '52',
#                                    'time': '24',
#                                    'uvIndex': '3',
#                                    'visibility': '10',
#                                    'visibilityMiles': '6',
#                                    'weatherCode': '113',
#                                    'weatherDesc': [{'value': 'Sunny'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#                                    'winddir16Point': 'WSW',
#                                    'winddirDegree': '238',
#                                    'windspeedKmph': '15',
#                                    'windspeedMiles': '9'}],
#                        'maxtempC': '11',
#                        'maxtempF': '52',
#                        'mintempC': '3',
#                        'mintempF': '37',
#                        'sunHour': '11.1',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '3'}]}}
# {'data': {'request': [{'query': 'New York, United States of America',
#                        'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '11',
#                                       'moon_phase': 'Waning Crescent',
#                                       'moonrise': '03:53 AM',
#                                       'moonset': '04:36 PM',
#                                       'sunrise': '07:30 AM',
#                                       'sunset': '05:49 PM'}],
#                        'avgtempC': '10',
#                        'avgtempF': '50',
#                        'date': '2018-11-04',
#                        'hourly': [{'DewPointC': '2',
#                                    'DewPointF': '36',
#                                    'FeelsLikeC': '11',
#                                    'FeelsLikeF': '52',
#                                    'HeatIndexC': '12',
#                                    'HeatIndexF': '54',
#                                    'WindChillC': '11',
#                                    'WindChillF': '52',
#                                    'WindGustKmph': '13',
#                                    'WindGustMiles': '8',
#                                    'cloudcover': '9',
#                                    'humidity': '51',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.0',
#                                    'pressure': '1032',
#                                    'pressureInches': '31',
#                                    'tempC': '13',
#                                    'tempF': '55',
#                                    'time': '24',
#                                    'uvIndex': '4',
#                                    'visibility': '10',
#                                    'visibilityMiles': '6',
#                                    'weatherCode': '113',
#                                    'weatherDesc': [{'value': 'Sunny'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#                                    'winddir16Point': 'SSE',
#                                    'winddirDegree': '167',
#                                    'windspeedKmph': '10',
#                                    'windspeedMiles': '6'}],
#                        'maxtempC': '13',
#                        'maxtempF': '55',
#                        'mintempC': '7',
#                        'mintempF': '45',
#                        'sunHour': '8.7',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '4'}]}}

# %%
majors_weather_dict = {
    "city": city_18_list,
    "feels_like_18": feel_18_list,
}
majors_18_weather_df = pd.DataFrame(majors_weather_dict)
majors_18_weather_df.head()
# Out:
#       city feels_like_18
# 0    Tokyo            42
# 1   Boston            38
# 2   London            65
# 3   Berlin            65
# 4  Chicago            40

# %%
merge_weather_1 = pd.merge(majors_13_weather_df, majors_14_weather_df, on="city")
merge_weather_1
# Out:
#        city feels_like_13 feels_like_14
# 0     Tokyo            33            34
# 1    Boston            43            48
# 2    London            47            49
# 3    Berlin            45            59
# 4   Chicago            55            50
# 5  New York            40            33

# %%
merge_weather_2 = pd.merge(merge_weather_1, majors_15_weather_df, on="city")
merge_weather_2
# Out:
#        city feels_like_13 feels_like_14 feels_like_15
# 0     Tokyo            33            34            44
# 1    Boston            43            48            41
# 2    London            47            49            45
# 3    Berlin            45            59            55
# 4   Chicago            55            50            60
# 5  New York            40            33            55

# %%
merge_weather_3 = pd.merge(merge_weather_2, majors_16_weather_df, on="city")
merge_weather_3
# Out:
#        city feels_like_13 feels_like_14 feels_like_15 feels_like_16
# 0     Tokyo            33            34            44            44
# 1    Boston            43            48            41            45
# 2    London            47            49            45            38
# 3    Berlin            45            59            55            60
# 4   Chicago            55            50            60            54
# 5  New York            40            33            55            47

# %%
merge_weather_4 = pd.merge(merge_weather_3, majors_17_weather_df, on="city")
merge_weather_4
# Out:
#        city feels_like_13 feels_like_14 feels_like_15 feels_like_16  \
# 0     Tokyo            33            34            44            44
# 1    Boston            43            48            41            45
# 2    London            47            49            45            38
# 3    Berlin            45            59            55            60
# 4   Chicago            55            50            60            54
# 5  New York            40            33            55            47
#
#   feels_like_17
# 0            36
# 1            64
# 2            47
# 3            59
# 4            67
# 5            57

# %%
merge_weather_5 = pd.merge(merge_weather_4, majors_18_weather_df, on="city")
merge_weather_5
merge_weather_5 = merge_weather_5.rename(columns={"feels_like_13":"2013", "feels_like_14":"2014", "feels_like_15":"2015","feels_like_16":"2016","feels_like_17":"2017","feels_like_18":"2018",})
merge_weather_5
# Out:
#        city 2013 2014 2015 2016 2017 2018
# 0     Tokyo   33   34   44   44   36   42
# 1    Boston   43   48   41   45   64   38
# 2    London   47   49   45   38   47   65
# 3    Berlin   45   59   55   60   59   65
# 4   Chicago   55   50   60   54   67   40
# 5  New York   40   33   55   47   57   52

# %%
merge_weather_df = pd.merge(merge_weather_5, city_codes_df, on="city")
merge_weather_df
# Out:
#        city 2013 2014 2015 2016 2017 2018 city_code
# 0     Tokyo   33   34   44   44   36   42       TYO
# 1    Boston   43   48   41   45   64   38       BOS
# 2    London   47   49   45   38   47   65       GBR
# 3    Berlin   45   59   55   60   59   65       BER
# 4   Chicago   55   50   60   54   67   40       CHI
# 5  New York   40   33   55   47   57   52       NYC

# %%
merge_weather_df = merge_weather_df.set_index("city_code")
merge_weather_df
# Out:
#                city 2013 2014 2015 2016 2017 2018
# city_code
# TYO           Tokyo   33   34   44   44   36   42
# BOS          Boston   43   48   41   45   64   38
# GBR          London   47   49   45   38   47   65
# BER          Berlin   45   59   55   60   59   65
# CHI         Chicago   55   50   60   54   67   40
# NYC        New York   40   33   55   47   57   52

# %%
merge_weather_df=merge_weather_df.astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-189-ba984bdb260b> in <module>
# ----> 1 merge_weather_df=merge_weather_df.astype(float)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
#    5692             return self._constructor(new_data).__finalize__(self)
#    5693
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     529
#     530     def astype(self, dtype, **kwargs):
# --> 531         return self.apply('astype', dtype=dtype, **kwargs)
#     532
#     533     def convert(self, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     393                                             copy=align_copy)
#     394
# --> 395             applied = getattr(b, f)(**kwargs)
#     396             result_blocks = _extend_blocks(applied, result_blocks)
#     397
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     532     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     533         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 534                             **kwargs)
#     535
#     536     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in _astype(self, dtype, copy, errors, values, **kwargs)
#     631
#     632                     # _astype_nansafe works fine with 1-d only
# --> 633                     values = astype_nansafe(values.ravel(), dtype, copy=True)
#     634
#     635                 # TODO(extension)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     700     if copy or is_object_dtype(arr) or is_object_dtype(dtype):
#     701         # Explicit copy, or required since NumPy can't view from / to object.
# --> 702         return arr.astype(dtype, copy=True)
#     703
#     704     return arr.view(dtype)
#
# ValueError: could not convert string to float: 'Tokyo'

# %%
average_heat_index = merge_weather_df.mean()
average_heat_index
print(average_heat_index)
# Out:
# Series([], dtype: float64)

# %%
# merge_weather_df.loc['TYO', "2013":"2018"].plot(label="Tokyo")
# plt.legend()
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-150-c9629b7d805d> in <module>
# ----> 1 merge_weather_df.loc['TYO', "2013":"2018"].plot(label="Tokyo")
#       2 plt.legend()
#       3 plt.show()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2740                            colormap=colormap, table=table, yerr=yerr,
#    2741                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2742                            **kwds)
#    2743     __call__.__doc__ = plot_series.__doc__
#    2744
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    1996                  yerr=yerr, xerr=xerr,
#    1997                  label=label, secondary_y=secondary_y,
# -> 1998                  **kwds)
#    1999
#    2000
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1799         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1800
# -> 1801     plot_obj.generate()
#    1802     plot_obj.draw()
#    1803     return plot_obj.result
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in generate(self)
#     247     def generate(self):
#     248         self._args_adjust()
# --> 249         self._compute_plot_data()
#     250         self._setup_subplots()
#     251         self._make_plot()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in _compute_plot_data(self)
#     365         if is_empty:
#     366             raise TypeError('Empty {0!r}: no numeric data to '
# --> 367                             'plot'.format(numeric_data.__class__.__name__))
#     368
#     369         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %%
average_heat_index = merge_weather_df.mean()
average_heat_index
merge_weather_df.mean()
# Out:
# Series([], dtype: float64)

# %%
# country_one, = plt.plot(years, merge_weather_df.loc['JPN',["2013","2014","2015","2016","2017","2018"]], color="green",label="Tokyo Marathon"
# plt.legend()
# plt.show

# %%
# Select two countries' worth of data.
heat_index_13 = merge_weather_df.loc[1]
heat_index_14 = merge_weather_df.loc[2]
heat_index_15 = merge_weather_df.loc[3]

# Plot with differently-colored markers.
years = [2013, 2014, 2015, 2016, 2017, 2018]
plt.plot(x= ["years"], y=["heat_index_13", "heat_index_14", "heat_index_15"], kind="bar")
# plt.plot(['city'], heat_index_13, 'b-', label='Majors 2013')
# plt.plot(['city'], heat_index_14, 'g-', label='Majors 2014')

# Create legend.
plt.legend()
plt.xlabel('Year')

# %%
merge_weather_df=merge_weather_df.astype(float)

# %%
merge_weather_df.plot.bar()
plt.legend(loc="best")
plt.title("Historical Heat Index At The Abbot Majors")
plt.xlabel("Country")
plt.ylabel("Number of Medals")

# %%
merge_weather_df.columns

# %%
merge_weather_df.set_index('city')

# %%
merge_weather_df.plot.bar()
plt.legend(loc="best")
plt.title("Historical Heat Index At The Abbot Majors")
plt.xlabel("Country")
plt.ylabel("Number of Medals")

# %%
rift_dates_csv = "Data/rift_weath_sol_equ.csv"

# %%
rift_dates_df = pd.read_csv(rift_dates_csv)
rift_dates_df
# Out:
#              city   sumsol_13   winsol_13   sprequ_13  fallequ_13   sumsol_14  \
# Bekoji   Ethiopia  2013-06-21  2013-12-21  2013-03-20  2013-09-23  2013-06-21
# Eldoret     Kenya  2013-06-21  2013-12-21  2013-03-20  2013-09-23  2013-06-21
#
#           winsol_14   sprequ_14  fallequ_14   sumsol_15  ...   sprequ_16  \
# Bekoji   2013-12-21  2013-03-20  2013-09-23  2013-06-21  ...  2013-03-20
# Eldoret  2013-12-21  2013-03-20  2013-09-23  2013-06-21  ...  2013-03-20
#
#          fallequ_16   sumsol_17   winsol_17   sprequ_17  fallequ_17  \
# Bekoji   2013-09-23  2013-06-21  2013-12-21  2013-03-20  2013-09-23
# Eldoret  2013-09-23  2013-06-21  2013-12-21  2013-03-20  2013-09-23
#
#           sumsol_18   winsol_18   sprequ_18  fallequ_18
# Bekoji   2013-06-21  2013-12-21  2013-03-20  2013-09-23
# Eldoret  2013-06-21  2013-12-21  2013-03-20  2013-09-23
#
# [2 rows x 25 columns]

# %%
city_rift_list = []
feel_rift_list = []

url = "https://api.worldweatheronline.com/premium/v1/past-weather.ashx"
params = {
    "key": "bc1fb38cb0ec446b83221156192908",  
    "tp": 24,
    "format": "json",    
}

for index, row in rift_dates_df.iterrows():
 
    params['q'] = row['city']
    params['date'] = row['sumsol_13']
    
    response = requests.get(url, params=params).json()
    
    city_rift_list.append(row['city'])
    feel_rift_list.append((response['data']['weather'][0]['hourly'][0]['FeelsLikeF']))
    pprint(response)
# Out:
# {'data': {'request': [{'query': 'Addis Abeba, Ethiopia', 'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '91',
#                                       'moon_phase': 'Waxing Gibbous',
#                                       'moonrise': '04:45 PM',
#                                       'moonset': '03:48 AM',
#                                       'sunrise': '06:07 AM',
#                                       'sunset': '06:46 PM'}],
#                        'avgtempC': '16',
#                        'avgtempF': '61',
#                        'date': '2013-06-21',
#                        'hourly': [{'DewPointC': '12',
#                                    'DewPointF': '53',
#                                    'FeelsLikeC': '17',
#                                    'FeelsLikeF': '63',
#                                    'HeatIndexC': '18',
#                                    'HeatIndexF': '64',
#                                    'WindChillC': '17',
#                                    'WindChillF': '63',
#                                    'WindGustKmph': '7',
#                                    'WindGustMiles': '4',
#                                    'cloudcover': '21',
#                                    'humidity': '73',
#                                    'precipInches': '0.0',
#                                    'precipMM': '1.2',
#                                    'pressure': '1014',
#                                    'pressureInches': '30',
#                                    'tempC': '22',
#                                    'tempF': '72',
#                                    'time': '24',
#                                    'uvIndex': '5',
#                                    'visibility': '9',
#                                    'visibilityMiles': '5',
#                                    'weatherCode': '113',
#                                    'weatherDesc': [{'value': 'Sunny'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#                                    'winddir16Point': 'S',
#                                    'winddirDegree': '191',
#                                    'windspeedKmph': '4',
#                                    'windspeedMiles': '3'}],
#                        'maxtempC': '22',
#                        'maxtempF': '72',
#                        'mintempC': '11',
#                        'mintempF': '52',
#                        'sunHour': '11.6',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '5'}]}}
# {'data': {'request': [{'query': 'Nairobi, Kenya', 'type': 'City'}],
#           'weather': [{'astronomy': [{'moon_illumination': '91',
#                                       'moon_phase': 'Waxing Gibbous',
#                                       'moonrise': '04:38 PM',
#                                       'moonset': '04:10 AM',
#                                       'sunrise': '06:33 AM',
#                                       'sunset': '06:36 PM'}],
#                        'avgtempC': '16',
#                        'avgtempF': '60',
#                        'date': '2013-06-21',
#                        'hourly': [{'DewPointC': '14',
#                                    'DewPointF': '58',
#                                    'FeelsLikeC': '16',
#                                    'FeelsLikeF': '61',
#                                    'HeatIndexC': '16',
#                                    'HeatIndexF': '61',
#                                    'WindChillC': '16',
#                                    'WindChillF': '61',
#                                    'WindGustKmph': '10',
#                                    'WindGustMiles': '6',
#                                    'cloudcover': '69',
#                                    'humidity': '89',
#                                    'precipInches': '0.0',
#                                    'precipMM': '0.7',
#                                    'pressure': '1018',
#                                    'pressureInches': '31',
#                                    'tempC': '19',
#                                    'tempF': '66',
#                                    'time': '24',
#                                    'uvIndex': '5',
#                                    'visibility': '7',
#                                    'visibilityMiles': '4',
#                                    'weatherCode': '116',
#                                    'weatherDesc': [{'value': 'Partly cloudy'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#                                    'winddir16Point': 'ESE',
#                                    'winddirDegree': '118',
#                                    'windspeedKmph': '7',
#                                    'windspeedMiles': '5'}],
#                        'maxtempC': '19',
#                        'maxtempF': '66',
#                        'mintempC': '14',
#                        'mintempF': '57',
#                        'sunHour': '10.2',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '5'}]}}

# %%
print(temp_rift_list)

# %%
major_dates_df

# %%
N = 5
menMeans = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)
menStd = (2, 3, 4, 1, 2)
womenStd = (3, 5, 2, 3, 3)
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, menMeans, width, yerr=menStd)
p2 = plt.bar(ind, womenMeans, width,
             bottom=menMeans, yerr=womenStd)

plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(ind, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0]), ('Men', 'Women'))

plt.show()
